# %%
import numpy
import pandas

boxes = ( 'A1','A2','A3','B1','B2','B3','C1','C2','C3' )
option = [ '_','_','_','_','_','_','_','_','_' ]

def print_board():
    print ( '  ',option[0],'  |  ',option[1],'  |  ',option[2],'  ' )
    print ( '———————————————————————' )
    print ( '  ',option[3],'  |  ',option[4],'  |  ',option[5],'  ' )
    print ( '———————————————————————' )
    print ( '  ',option[6],'  |  ',option[7],'  |  ',option[8],'  ' )
    
player_one = True
turn = 0
one = []
two = []

def win( moves ):
    winning = [ [ 2,4,6 ], [ 0,4,8 ], [ 6,7,8 ], [ 3,4,5 ], [ 3,5,8 ], [ 1,4,7 ], [ 0,3,6 ], [ 0,1,2 ] ]
    for l in winning:
        n = len( set( l ) & set( moves ) )
        if n == 3:
            return True
    return False

while turn < 9:
    position = input( "Choose a position: " )
    if position in boxes:
        if position == boxes[0]:
            if option[0] in ( 'X','O' ):
                print( "Your selection is invalid." )
            else:
                if player_one is True:
                    option[0] = 'X'
                    one.append( 0 )
                    moves = one
                    if win( moves ):
                        print_board()
                        print( "Player One wins!" )
                        turn = 10
                    else:
                        turn = turn + 1
                        print_board()
                        player_one = not player_one 
                else:
                    option[0] = 'O'
                    two.append( 0 )
                    moves = two
                    if win ( moves ):
                        print_board()
                        print( "Player Two wins!" )
                        turn = 10
                    else:
                        turn = turn + 1
                        print_board()
                        player_one = not player_one 
        if position == boxes[1]:
            if option[1] in ( 'X','O' ):
                print( "Your selection is invalid." )
            else:
                if player_one is True:
                    option[1] = 'X'
                    one.append( 1 )
                    moves = one
                    if win( moves ):
                        print_board()
                        print( "Player One wins!" )
                        turn = 10
                    else:
                        turn = turn + 1
                        print_board()
                        player_one = not player_one 
                else:
                    option[1] = 'O'
                    two.append( 1 )
                    moves = two
                    if win ( moves ):
                        print_board()
                        print( "Player Two wins!" )
                        turn = 10
                    else:
                        turn = turn + 1
                        print_board()
                        player_one = not player_one 
        if position == boxes[2]:
            if option[2] in ( 'X','O' ):
                print( "Your selection is invalid." )
            else:
                if player_one is True:
                    option[2] = 'X'
                    one.append( 2 )
                    moves = one
                    if win( moves ):
                        print_board()
                        print( "Player One wins!" )
                        turn = 10
                    else:
                        turn = turn + 1
                        print_board()
                        player_one = not player_one 
                else:
                    option[2] = 'O'
                    two.append( 2 )
                    moves = two
                    if win ( moves ):
                        print_board()
                        print( "Player Two wins!" )
                        turn = 10
                    else:
                        turn = turn + 1
                        print_board()
                        player_one = not player_one 
        if position == boxes[3]:
            if option[3] in ( 'X','O' ):
                print( "Your selection is invalid." )
            else:
                if player_one is True:
                    option[3] = 'X'
                    one.append( 3 )
                    moves = one
                    if win( moves ):
                        print_board()
                        print( "Player One wins!" )
                        turn = 10
                    else:
                        turn = turn + 1
                        print_board()
                        player_one = not player_one 
                else:
                    option[3] = 'O'
                    two.append( 3 )
                    moves = two
                    if win ( moves ):
                        print_board()
                        print( "Player Two wins!" )
                        turn = 10
                    else:
                        turn = turn + 1
                        print_board()
                        player_one = not player_one 
        if position == boxes[4]:
            if option[4] in ( 'X','O' ):
                print( "Your selection is invalid." )
            else:
                if player_one is True:
                    option[4] = 'X'
                    one.append( 4 )
                    moves = one
                    if win( moves ):
                        print_board()
                        print( "Player One wins!" )
                        turn = 10
                    else:
                        turn = turn + 1
                        print_board()
                        player_one = not player_one 
                else:
                    option[4] = 'O'
                    two.append( 4 )
                    moves = two
                    if win ( moves ):
                        print_board()
                        print( "Player Two wins!" )
                        turn = 10
                    else:
                        turn = turn + 1
                        print_board()
                        player_one = not player_one 
        if position == boxes[5]:
            if option[5] in ( 'X','O' ):
                print( "Your selection is invalid." )
            else:
                if player_one is True:
                    option[5] = 'X'
                    one.append( 5 )
                    moves = one
                    if win( moves ):
                        print_board()
                        print( "Player One wins!" )
                        turn = 10
                    else:
                        turn = turn + 1
                        print_board()
                        player_one = not player_one 
                else:
                    option[5] = 'O'
                    two.append( 5 )
                    moves = two
                    if win ( moves ):
                        print_board()
                        print( "Player Two wins!" )
                        turn = 10
                    else:
                        turn = turn + 1
                        print_board()
                        player_one = not player_one 
        if position == boxes[6]:
            if option[6] in ( 'X','O' ):
                print( "Your selection is invalid." )
            else:
                if player_one is True:
                    option[6] = 'X'
                    one.append( 6 )
                    moves = one
                    if win( moves ):
                        print_board()
                        print( "Player One wins!" )
                        turn = 10
                    else:
                        turn = turn + 1
                        print_board()
                        player_one = not player_one 
                else:
                    option[6] = 'O'
                    two.append( 6 )
                    moves = two
                    if win ( moves ):
                        print_board()
                        print( "Player Two wins!" )
                        turn = 10
                    else:
                        turn = turn + 1
                        print_board()
                        player_one = not player_one 
        if position == boxes[7]:
            if option[7] in ( 'X','O' ):
                print( "Your selection is invalid." )
            else:
                if player_one is True:
                    option[7] = 'X'
                    one.append( 7 )
                    moves = one
                    if win( moves ):
                        print_board()
                        print( "Player One wins!" )
                        turn = 10
                    else:
                        turn = turn + 1
                        print_board()
                        player_one = not player_one 
                else:
                    option[7] = 'O'
                    two.append( 7 )
                    moves = two
                    if win ( moves ):
                        print_board()
                        print( "Player Two wins!" )
                        turn = 10
                    else:
                        turn = turn + 1
                        print_board()
                        player_one = not player_one 
        if position == boxes[8]:
            if option[8] in ( 'X','O' ):
                print( "Your selection is invalid." )
            else:
                if player_one is True:
                    option[8] = 'X'
                    one.append( 8 )
                    moves = one
                    if win( moves ):
                        print_board()
                        print( "Player One wins!" )
                        turn = 10
                    else:
                        turn = turn + 1
                        print_board()
                        player_one = not player_one 
                else:
                    option[8] = 'O'
                    two.append( 8 )
                    moves = two
                    if win ( moves ):
                        print_board()
                        print( "Player Two wins!" )
                        turn = 10
                    else:
                        turn = turn + 1
                        print_board()
                        player_one = not player_one 
    else:
        print( "Your selection is invalid." )
else:
    print( "Game Over" )
